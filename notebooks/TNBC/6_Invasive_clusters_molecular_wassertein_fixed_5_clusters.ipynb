# %%
import pandas as pd

import os

import numpy as np


import matplotlib.pyplot as plt
import seaborn as sns

import anndata as ad
import glob


import warnings
warnings.filterwarnings("ignore")

import matplotlib
matplotlib.rcParams["pdf.fonttype"] = 42
matplotlib.rcParams["ps.fonttype"] = 42

import json

# %%
# Load configuration
with open("../../config/config_notebooks_TNBC.json", "r") as config_file:
    config = json.load(config_file)

a = config['retrained_color_palette']

# %%
# Retrieve patient names and loop through them
patient_list = [f"TNBC{i}" for i in range(1, 97)]

patients_to_remove = []
for patient in patient_list:
    for model_type, names, benchmark_path in zip([config['retrained_model_list1_type'],
                                  config['retrained_model_list2_type']],
                                  [config['retrained_model_list1'],
                                   config['retrained_model_list2']],
                                   [config['retrained_benchmark_folder1'],
                                    config['retrained_benchmark_folder2']]):
        for name in names:
            if os.path.exists(os.path.join(benchmark_path, "invasive_cancer_clustering", "kmeans", name, f"quantized_wasserstein_distance_molecular_combat_corrected_{name}_5_clusters_patient_{patient}.csv")) == False:
                patients_to_remove.append(patient)
                print(f"Removed patient {patient} as file does not exist")

# remove all patients in patients_to_remove from patient_list
patients_to_remove_set = set(patients_to_remove)
original_len = len(patient_list)
patient_list = [p for p in patient_list if p not in patients_to_remove_set]
print(f"Removed {original_len - len(patient_list)} patients; remaining {len(patient_list)} patients.")
# Out:
# File does not exist for patient TNBC1, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC1 as file does not exist
# File does not exist for patient TNBC1, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC1 as file does not exist
# File does not exist for patient TNBC1, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC1 as file does not exist
# File does not exist for patient TNBC1, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC1 as file does not exist
# File does not exist for patient TNBC1, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC1 as file does not exist
# File does not exist for patient TNBC1, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC1 as file does not exist
# File does not exist for patient TNBC1, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC1 as file does not exist
# File does not exist for patient TNBC1, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC1 as file does not exist
# File does not exist for patient TNBC1, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC1 as file does not exist
# File does not exist for patient TNBC1, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC1 as file does not exist
# File does not exist for patient TNBC1, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC1 as file does not exist
# File does not exist for patient TNBC2, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC2 as file does not exist
# File does not exist for patient TNBC2, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC2 as file does not exist
# File does not exist for patient TNBC2, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC2 as file does not exist
# File does not exist for patient TNBC2, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC2 as file does not exist
# File does not exist for patient TNBC2, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC2 as file does not exist
# File does not exist for patient TNBC2, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC2 as file does not exist
# File does not exist for patient TNBC2, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC2 as file does not exist
# File does not exist for patient TNBC2, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC2 as file does not exist
# File does not exist for patient TNBC2, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC2 as file does not exist
# File does not exist for patient TNBC2, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC2 as file does not exist
# File does not exist for patient TNBC2, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC2 as file does not exist
# File does not exist for patient TNBC3, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC3 as file does not exist
# File does not exist for patient TNBC3, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC3 as file does not exist
# File does not exist for patient TNBC3, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC3 as file does not exist
# File does not exist for patient TNBC3, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC3 as file does not exist
# File does not exist for patient TNBC3, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC3 as file does not exist
# File does not exist for patient TNBC3, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC3 as file does not exist
# File does not exist for patient TNBC3, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC3 as file does not exist
# File does not exist for patient TNBC3, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC3 as file does not exist
# File does not exist for patient TNBC3, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC3 as file does not exist
# File does not exist for patient TNBC3, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC3 as file does not exist
# File does not exist for patient TNBC3, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC3 as file does not exist
# File does not exist for patient TNBC4, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC4 as file does not exist
# File does not exist for patient TNBC4, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC4 as file does not exist
# File does not exist for patient TNBC4, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC4 as file does not exist
# File does not exist for patient TNBC4, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC4 as file does not exist
# File does not exist for patient TNBC4, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC4 as file does not exist
# File does not exist for patient TNBC4, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC4 as file does not exist
# File does not exist for patient TNBC4, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC4 as file does not exist
# File does not exist for patient TNBC4, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC4 as file does not exist
# File does not exist for patient TNBC4, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC4 as file does not exist
# File does not exist for patient TNBC4, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC4 as file does not exist
# File does not exist for patient TNBC4, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC4 as file does not exist
# File does not exist for patient TNBC5, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC5 as file does not exist
# File does not exist for patient TNBC5, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC5 as file does not exist
# File does not exist for patient TNBC5, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC5 as file does not exist
# File does not exist for patient TNBC5, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC5 as file does not exist
# File does not exist for patient TNBC5, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC5 as file does not exist
# File does not exist for patient TNBC5, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC5 as file does not exist
# File does not exist for patient TNBC5, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC5 as file does not exist
# File does not exist for patient TNBC5, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC5 as file does not exist
# File does not exist for patient TNBC5, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC5 as file does not exist
# File does not exist for patient TNBC5, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC5 as file does not exist
# File does not exist for patient TNBC5, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC5 as file does not exist
# File does not exist for patient TNBC6, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC6 as file does not exist
# File does not exist for patient TNBC6, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC6 as file does not exist
# File does not exist for patient TNBC6, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC6 as file does not exist
# File does not exist for patient TNBC6, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC6 as file does not exist
# File does not exist for patient TNBC6, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC6 as file does not exist
# File does not exist for patient TNBC6, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC6 as file does not exist
# File does not exist for patient TNBC6, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC6 as file does not exist
# File does not exist for patient TNBC6, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC6 as file does not exist
# File does not exist for patient TNBC6, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC6 as file does not exist
# File does not exist for patient TNBC6, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC6 as file does not exist
# File does not exist for patient TNBC6, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC6 as file does not exist
# File does not exist for patient TNBC7, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC7 as file does not exist
# File does not exist for patient TNBC7, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC7 as file does not exist
# File does not exist for patient TNBC7, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC7 as file does not exist
# File does not exist for patient TNBC7, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC7 as file does not exist
# File does not exist for patient TNBC7, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC7 as file does not exist
# File does not exist for patient TNBC7, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC7 as file does not exist
# File does not exist for patient TNBC7, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC7 as file does not exist
# File does not exist for patient TNBC7, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC7 as file does not exist
# File does not exist for patient TNBC7, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC7 as file does not exist
# File does not exist for patient TNBC7, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC7 as file does not exist
# File does not exist for patient TNBC7, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC7 as file does not exist
# File does not exist for patient TNBC8, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC8 as file does not exist
# File does not exist for patient TNBC8, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC8 as file does not exist
# File does not exist for patient TNBC8, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC8 as file does not exist
# File does not exist for patient TNBC8, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC8 as file does not exist
# File does not exist for patient TNBC8, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC8 as file does not exist
# File does not exist for patient TNBC8, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC8 as file does not exist
# File does not exist for patient TNBC8, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC8 as file does not exist
# File does not exist for patient TNBC8, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC8 as file does not exist
# File does not exist for patient TNBC8, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC8 as file does not exist
# File does not exist for patient TNBC8, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC8 as file does not exist
# File does not exist for patient TNBC8, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC8 as file does not exist
# File does not exist for patient TNBC9, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC9 as file does not exist
# File does not exist for patient TNBC9, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC9 as file does not exist
# File does not exist for patient TNBC9, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC9 as file does not exist
# File does not exist for patient TNBC9, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC9 as file does not exist
# File does not exist for patient TNBC9, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC9 as file does not exist
# File does not exist for patient TNBC9, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC9 as file does not exist
# File does not exist for patient TNBC9, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC9 as file does not exist
# File does not exist for patient TNBC9, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC9 as file does not exist
# File does not exist for patient TNBC9, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC9 as file does not exist
# File does not exist for patient TNBC9, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC9 as file does not exist
# File does not exist for patient TNBC9, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC9 as file does not exist
# File does not exist for patient TNBC10, model uni, type explora
# Removed patient TNBC10 as file does not exist
# File does not exist for patient TNBC10, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC10 as file does not exist
# File does not exist for patient TNBC10, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC10 as file does not exist
# File does not exist for patient TNBC10, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC10 as file does not exist
# File does not exist for patient TNBC10, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC10 as file does not exist
# File does not exist for patient TNBC10, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC10 as file does not exist
# File does not exist for patient TNBC10, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC10 as file does not exist
# File does not exist for patient TNBC10, model uni, type full
# Removed patient TNBC10 as file does not exist
# File does not exist for patient TNBC10, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC10 as file does not exist
# File does not exist for patient TNBC10, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC10 as file does not exist
# File does not exist for patient TNBC10, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC10 as file does not exist
# File does not exist for patient TNBC10, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC10 as file does not exist
# File does not exist for patient TNBC10, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC10 as file does not exist
# File does not exist for patient TNBC10, model uni_full_koleo_65536_prototypes, type full
# Removed patient TNBC10 as file does not exist
# File does not exist for patient TNBC11, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC11 as file does not exist
# File does not exist for patient TNBC11, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC11 as file does not exist
# File does not exist for patient TNBC11, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC11 as file does not exist
# File does not exist for patient TNBC11, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC11 as file does not exist
# File does not exist for patient TNBC11, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC11 as file does not exist
# File does not exist for patient TNBC11, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC11 as file does not exist
# File does not exist for patient TNBC11, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC11 as file does not exist
# File does not exist for patient TNBC11, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC11 as file does not exist
# File does not exist for patient TNBC11, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC11 as file does not exist
# File does not exist for patient TNBC11, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC11 as file does not exist
# File does not exist for patient TNBC11, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC11 as file does not exist
# File does not exist for patient TNBC12, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC12 as file does not exist
# File does not exist for patient TNBC12, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC12 as file does not exist
# File does not exist for patient TNBC12, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC12 as file does not exist
# File does not exist for patient TNBC12, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC12 as file does not exist
# File does not exist for patient TNBC12, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC12 as file does not exist
# File does not exist for patient TNBC12, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC12 as file does not exist
# File does not exist for patient TNBC12, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC12 as file does not exist
# File does not exist for patient TNBC12, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC12 as file does not exist
# File does not exist for patient TNBC12, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC12 as file does not exist
# File does not exist for patient TNBC12, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC12 as file does not exist
# File does not exist for patient TNBC12, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC12 as file does not exist
# File does not exist for patient TNBC13, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC13 as file does not exist
# File does not exist for patient TNBC13, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC13 as file does not exist
# File does not exist for patient TNBC13, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC13 as file does not exist
# File does not exist for patient TNBC13, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC13 as file does not exist
# File does not exist for patient TNBC13, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC13 as file does not exist
# File does not exist for patient TNBC13, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC13 as file does not exist
# File does not exist for patient TNBC13, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC13 as file does not exist
# File does not exist for patient TNBC13, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC13 as file does not exist
# File does not exist for patient TNBC13, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC13 as file does not exist
# File does not exist for patient TNBC13, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC13 as file does not exist
# File does not exist for patient TNBC13, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC13 as file does not exist
# File does not exist for patient TNBC14, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC14 as file does not exist
# File does not exist for patient TNBC14, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC14 as file does not exist
# File does not exist for patient TNBC14, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC14 as file does not exist
# File does not exist for patient TNBC14, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC14 as file does not exist
# File does not exist for patient TNBC14, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC14 as file does not exist
# File does not exist for patient TNBC14, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC14 as file does not exist
# File does not exist for patient TNBC14, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC14 as file does not exist
# File does not exist for patient TNBC14, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC14 as file does not exist
# File does not exist for patient TNBC14, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC14 as file does not exist
# File does not exist for patient TNBC14, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC14 as file does not exist
# File does not exist for patient TNBC14, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC14 as file does not exist
# File does not exist for patient TNBC15, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC15 as file does not exist
# File does not exist for patient TNBC15, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC15 as file does not exist
# File does not exist for patient TNBC15, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC15 as file does not exist
# File does not exist for patient TNBC15, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC15 as file does not exist
# File does not exist for patient TNBC15, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC15 as file does not exist
# File does not exist for patient TNBC15, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC15 as file does not exist
# File does not exist for patient TNBC15, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC15 as file does not exist
# File does not exist for patient TNBC15, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC15 as file does not exist
# File does not exist for patient TNBC15, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC15 as file does not exist
# File does not exist for patient TNBC15, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC15 as file does not exist
# File does not exist for patient TNBC15, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC15 as file does not exist
# File does not exist for patient TNBC16, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC16 as file does not exist
# File does not exist for patient TNBC16, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC16 as file does not exist
# File does not exist for patient TNBC16, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC16 as file does not exist
# File does not exist for patient TNBC16, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC16 as file does not exist
# File does not exist for patient TNBC16, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC16 as file does not exist
# File does not exist for patient TNBC16, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC16 as file does not exist
# File does not exist for patient TNBC16, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC16 as file does not exist
# File does not exist for patient TNBC16, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC16 as file does not exist
# File does not exist for patient TNBC16, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC16 as file does not exist
# File does not exist for patient TNBC16, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC16 as file does not exist
# File does not exist for patient TNBC16, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC16 as file does not exist
# File does not exist for patient TNBC17, model uni, type explora
# Removed patient TNBC17 as file does not exist
# File does not exist for patient TNBC17, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC17 as file does not exist
# File does not exist for patient TNBC17, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC17 as file does not exist
# File does not exist for patient TNBC17, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC17 as file does not exist
# File does not exist for patient TNBC17, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC17 as file does not exist
# File does not exist for patient TNBC17, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC17 as file does not exist
# File does not exist for patient TNBC17, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC17 as file does not exist
# File does not exist for patient TNBC17, model uni, type full
# Removed patient TNBC17 as file does not exist
# File does not exist for patient TNBC17, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC17 as file does not exist
# File does not exist for patient TNBC17, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC17 as file does not exist
# File does not exist for patient TNBC17, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC17 as file does not exist
# File does not exist for patient TNBC17, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC17 as file does not exist
# File does not exist for patient TNBC17, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC17 as file does not exist
# File does not exist for patient TNBC17, model uni_full_koleo_65536_prototypes, type full
# Removed patient TNBC17 as file does not exist
# File does not exist for patient TNBC18, model uni, type explora
# Removed patient TNBC18 as file does not exist
# File does not exist for patient TNBC18, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC18 as file does not exist
# File does not exist for patient TNBC18, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC18 as file does not exist
# File does not exist for patient TNBC18, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC18 as file does not exist
# File does not exist for patient TNBC18, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC18 as file does not exist
# File does not exist for patient TNBC18, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC18 as file does not exist
# File does not exist for patient TNBC18, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC18 as file does not exist
# File does not exist for patient TNBC18, model uni, type full
# Removed patient TNBC18 as file does not exist
# File does not exist for patient TNBC18, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC18 as file does not exist
# File does not exist for patient TNBC18, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC18 as file does not exist
# File does not exist for patient TNBC18, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC18 as file does not exist
# File does not exist for patient TNBC18, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC18 as file does not exist
# File does not exist for patient TNBC18, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC18 as file does not exist
# File does not exist for patient TNBC18, model uni_full_koleo_65536_prototypes, type full
# Removed patient TNBC18 as file does not exist
# File does not exist for patient TNBC19, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC19 as file does not exist
# File does not exist for patient TNBC19, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC19 as file does not exist
# File does not exist for patient TNBC19, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC19 as file does not exist
# File does not exist for patient TNBC19, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC19 as file does not exist
# File does not exist for patient TNBC19, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC19 as file does not exist
# File does not exist for patient TNBC19, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC19 as file does not exist
# File does not exist for patient TNBC19, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC19 as file does not exist
# File does not exist for patient TNBC19, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC19 as file does not exist
# File does not exist for patient TNBC19, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC19 as file does not exist
# File does not exist for patient TNBC19, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC19 as file does not exist
# File does not exist for patient TNBC19, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC19 as file does not exist
# File does not exist for patient TNBC20, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC20 as file does not exist
# File does not exist for patient TNBC20, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC20 as file does not exist
# File does not exist for patient TNBC20, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC20 as file does not exist
# File does not exist for patient TNBC20, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC20 as file does not exist
# File does not exist for patient TNBC20, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC20 as file does not exist
# File does not exist for patient TNBC20, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC20 as file does not exist
# File does not exist for patient TNBC20, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC20 as file does not exist
# File does not exist for patient TNBC20, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC20 as file does not exist
# File does not exist for patient TNBC20, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC20 as file does not exist
# File does not exist for patient TNBC20, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC20 as file does not exist
# File does not exist for patient TNBC20, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC20 as file does not exist
# File does not exist for patient TNBC21, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC21 as file does not exist
# File does not exist for patient TNBC21, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC21 as file does not exist
# File does not exist for patient TNBC21, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC21 as file does not exist
# File does not exist for patient TNBC21, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC21 as file does not exist
# File does not exist for patient TNBC21, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC21 as file does not exist
# File does not exist for patient TNBC21, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC21 as file does not exist
# File does not exist for patient TNBC21, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC21 as file does not exist
# File does not exist for patient TNBC21, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC21 as file does not exist
# File does not exist for patient TNBC21, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC21 as file does not exist
# File does not exist for patient TNBC21, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC21 as file does not exist
# File does not exist for patient TNBC21, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC21 as file does not exist
# File does not exist for patient TNBC22, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC22 as file does not exist
# File does not exist for patient TNBC22, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC22 as file does not exist
# File does not exist for patient TNBC22, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC22 as file does not exist
# File does not exist for patient TNBC22, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC22 as file does not exist
# File does not exist for patient TNBC22, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC22 as file does not exist
# File does not exist for patient TNBC22, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC22 as file does not exist
# File does not exist for patient TNBC22, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC22 as file does not exist
# File does not exist for patient TNBC22, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC22 as file does not exist
# File does not exist for patient TNBC22, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC22 as file does not exist
# File does not exist for patient TNBC22, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC22 as file does not exist
# File does not exist for patient TNBC22, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC22 as file does not exist
# File does not exist for patient TNBC23, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC23 as file does not exist
# File does not exist for patient TNBC23, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC23 as file does not exist
# File does not exist for patient TNBC23, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC23 as file does not exist
# File does not exist for patient TNBC23, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC23 as file does not exist
# File does not exist for patient TNBC23, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC23 as file does not exist
# File does not exist for patient TNBC23, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC23 as file does not exist
# File does not exist for patient TNBC23, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC23 as file does not exist
# File does not exist for patient TNBC23, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC23 as file does not exist
# File does not exist for patient TNBC23, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC23 as file does not exist
# File does not exist for patient TNBC23, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC23 as file does not exist
# File does not exist for patient TNBC23, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC23 as file does not exist
# File does not exist for patient TNBC24, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC24 as file does not exist
# File does not exist for patient TNBC24, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC24 as file does not exist
# File does not exist for patient TNBC24, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC24 as file does not exist
# File does not exist for patient TNBC24, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC24 as file does not exist
# File does not exist for patient TNBC24, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC24 as file does not exist
# File does not exist for patient TNBC24, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC24 as file does not exist
# File does not exist for patient TNBC24, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC24 as file does not exist
# File does not exist for patient TNBC24, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC24 as file does not exist
# File does not exist for patient TNBC24, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC24 as file does not exist
# File does not exist for patient TNBC24, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC24 as file does not exist
# File does not exist for patient TNBC24, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC24 as file does not exist
# File does not exist for patient TNBC25, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC25 as file does not exist
# File does not exist for patient TNBC25, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC25 as file does not exist
# File does not exist for patient TNBC25, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC25 as file does not exist
# File does not exist for patient TNBC25, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC25 as file does not exist
# File does not exist for patient TNBC25, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC25 as file does not exist
# File does not exist for patient TNBC25, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC25 as file does not exist
# File does not exist for patient TNBC25, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC25 as file does not exist
# File does not exist for patient TNBC25, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC25 as file does not exist
# File does not exist for patient TNBC25, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC25 as file does not exist
# File does not exist for patient TNBC25, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC25 as file does not exist
# File does not exist for patient TNBC25, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC25 as file does not exist
# File does not exist for patient TNBC26, model uni, type explora
# Removed patient TNBC26 as file does not exist
# File does not exist for patient TNBC26, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC26 as file does not exist
# File does not exist for patient TNBC26, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC26 as file does not exist
# File does not exist for patient TNBC26, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC26 as file does not exist
# File does not exist for patient TNBC26, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC26 as file does not exist
# File does not exist for patient TNBC26, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC26 as file does not exist
# File does not exist for patient TNBC26, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC26 as file does not exist
# File does not exist for patient TNBC26, model uni, type full
# Removed patient TNBC26 as file does not exist
# File does not exist for patient TNBC26, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC26 as file does not exist
# File does not exist for patient TNBC26, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC26 as file does not exist
# File does not exist for patient TNBC26, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC26 as file does not exist
# File does not exist for patient TNBC26, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC26 as file does not exist
# File does not exist for patient TNBC26, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC26 as file does not exist
# File does not exist for patient TNBC26, model uni_full_koleo_65536_prototypes, type full
# Removed patient TNBC26 as file does not exist
# File does not exist for patient TNBC27, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC27 as file does not exist
# File does not exist for patient TNBC27, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC27 as file does not exist
# File does not exist for patient TNBC27, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC27 as file does not exist
# File does not exist for patient TNBC27, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC27 as file does not exist
# File does not exist for patient TNBC27, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC27 as file does not exist
# File does not exist for patient TNBC27, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC27 as file does not exist
# File does not exist for patient TNBC27, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC27 as file does not exist
# File does not exist for patient TNBC27, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC27 as file does not exist
# File does not exist for patient TNBC27, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC27 as file does not exist
# File does not exist for patient TNBC27, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC27 as file does not exist
# File does not exist for patient TNBC27, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC27 as file does not exist
# File does not exist for patient TNBC28, model uni, type explora
# Removed patient TNBC28 as file does not exist
# File does not exist for patient TNBC28, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC28 as file does not exist
# File does not exist for patient TNBC28, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC28 as file does not exist
# File does not exist for patient TNBC28, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC28 as file does not exist
# File does not exist for patient TNBC28, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC28 as file does not exist
# File does not exist for patient TNBC28, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC28 as file does not exist
# File does not exist for patient TNBC28, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC28 as file does not exist
# File does not exist for patient TNBC28, model uni, type full
# Removed patient TNBC28 as file does not exist
# File does not exist for patient TNBC28, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC28 as file does not exist
# File does not exist for patient TNBC28, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC28 as file does not exist
# File does not exist for patient TNBC28, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC28 as file does not exist
# File does not exist for patient TNBC28, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC28 as file does not exist
# File does not exist for patient TNBC28, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC28 as file does not exist
# File does not exist for patient TNBC28, model uni_full_koleo_65536_prototypes, type full
# Removed patient TNBC28 as file does not exist
# File does not exist for patient TNBC29, model uni, type explora
# Removed patient TNBC29 as file does not exist
# File does not exist for patient TNBC29, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC29 as file does not exist
# File does not exist for patient TNBC29, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC29 as file does not exist
# File does not exist for patient TNBC29, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC29 as file does not exist
# File does not exist for patient TNBC29, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC29 as file does not exist
# File does not exist for patient TNBC29, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC29 as file does not exist
# File does not exist for patient TNBC29, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC29 as file does not exist
# File does not exist for patient TNBC29, model uni, type full
# Removed patient TNBC29 as file does not exist
# File does not exist for patient TNBC29, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC29 as file does not exist
# File does not exist for patient TNBC29, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC29 as file does not exist
# File does not exist for patient TNBC29, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC29 as file does not exist
# File does not exist for patient TNBC29, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC29 as file does not exist
# File does not exist for patient TNBC29, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC29 as file does not exist
# File does not exist for patient TNBC29, model uni_full_koleo_65536_prototypes, type full
# Removed patient TNBC29 as file does not exist
# File does not exist for patient TNBC30, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC30 as file does not exist
# File does not exist for patient TNBC30, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC30 as file does not exist
# File does not exist for patient TNBC30, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC30 as file does not exist
# File does not exist for patient TNBC30, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC30 as file does not exist
# File does not exist for patient TNBC30, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC30 as file does not exist
# File does not exist for patient TNBC30, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC30 as file does not exist
# File does not exist for patient TNBC30, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC30 as file does not exist
# File does not exist for patient TNBC30, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC30 as file does not exist
# File does not exist for patient TNBC30, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC30 as file does not exist
# File does not exist for patient TNBC30, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC30 as file does not exist
# File does not exist for patient TNBC30, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC30 as file does not exist
# File does not exist for patient TNBC31, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC31 as file does not exist
# File does not exist for patient TNBC31, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC31 as file does not exist
# File does not exist for patient TNBC31, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC31 as file does not exist
# File does not exist for patient TNBC31, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC31 as file does not exist
# File does not exist for patient TNBC31, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC31 as file does not exist
# File does not exist for patient TNBC31, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC31 as file does not exist
# File does not exist for patient TNBC31, model uni_full_kde_4096_prototypes, type full
# ...
# File does not exist for patient TNBC86, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC86 as file does not exist
# File does not exist for patient TNBC86, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC86 as file does not exist
# File does not exist for patient TNBC86, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC86 as file does not exist
# File does not exist for patient TNBC86, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC86 as file does not exist
# File does not exist for patient TNBC87, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC87 as file does not exist
# File does not exist for patient TNBC87, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC87 as file does not exist
# File does not exist for patient TNBC87, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC87 as file does not exist
# File does not exist for patient TNBC87, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC87 as file does not exist
# File does not exist for patient TNBC87, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC87 as file does not exist
# File does not exist for patient TNBC87, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC87 as file does not exist
# File does not exist for patient TNBC87, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC87 as file does not exist
# File does not exist for patient TNBC87, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC87 as file does not exist
# File does not exist for patient TNBC87, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC87 as file does not exist
# File does not exist for patient TNBC87, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC87 as file does not exist
# File does not exist for patient TNBC87, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC87 as file does not exist
# File does not exist for patient TNBC88, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC88 as file does not exist
# File does not exist for patient TNBC88, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC88 as file does not exist
# File does not exist for patient TNBC88, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC88 as file does not exist
# File does not exist for patient TNBC88, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC88 as file does not exist
# File does not exist for patient TNBC88, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC88 as file does not exist
# File does not exist for patient TNBC88, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC88 as file does not exist
# File does not exist for patient TNBC88, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC88 as file does not exist
# File does not exist for patient TNBC88, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC88 as file does not exist
# File does not exist for patient TNBC88, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC88 as file does not exist
# File does not exist for patient TNBC88, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC88 as file does not exist
# File does not exist for patient TNBC88, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC88 as file does not exist
# File does not exist for patient TNBC89, model uni, type explora
# Removed patient TNBC89 as file does not exist
# File does not exist for patient TNBC89, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC89 as file does not exist
# File does not exist for patient TNBC89, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC89 as file does not exist
# File does not exist for patient TNBC89, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC89 as file does not exist
# File does not exist for patient TNBC89, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC89 as file does not exist
# File does not exist for patient TNBC89, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC89 as file does not exist
# File does not exist for patient TNBC89, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC89 as file does not exist
# File does not exist for patient TNBC89, model uni, type full
# Removed patient TNBC89 as file does not exist
# File does not exist for patient TNBC89, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC89 as file does not exist
# File does not exist for patient TNBC89, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC89 as file does not exist
# File does not exist for patient TNBC89, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC89 as file does not exist
# File does not exist for patient TNBC89, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC89 as file does not exist
# File does not exist for patient TNBC89, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC89 as file does not exist
# File does not exist for patient TNBC89, model uni_full_koleo_65536_prototypes, type full
# Removed patient TNBC89 as file does not exist
# File does not exist for patient TNBC90, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC90 as file does not exist
# File does not exist for patient TNBC90, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC90 as file does not exist
# File does not exist for patient TNBC90, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC90 as file does not exist
# File does not exist for patient TNBC90, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC90 as file does not exist
# File does not exist for patient TNBC90, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC90 as file does not exist
# File does not exist for patient TNBC90, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC90 as file does not exist
# File does not exist for patient TNBC90, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC90 as file does not exist
# File does not exist for patient TNBC90, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC90 as file does not exist
# File does not exist for patient TNBC90, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC90 as file does not exist
# File does not exist for patient TNBC90, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC90 as file does not exist
# File does not exist for patient TNBC90, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC90 as file does not exist
# File does not exist for patient TNBC91, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC91 as file does not exist
# File does not exist for patient TNBC91, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC91 as file does not exist
# File does not exist for patient TNBC91, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC91 as file does not exist
# File does not exist for patient TNBC91, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC91 as file does not exist
# File does not exist for patient TNBC91, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC91 as file does not exist
# File does not exist for patient TNBC91, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC91 as file does not exist
# File does not exist for patient TNBC91, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC91 as file does not exist
# File does not exist for patient TNBC91, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC91 as file does not exist
# File does not exist for patient TNBC91, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC91 as file does not exist
# File does not exist for patient TNBC91, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC91 as file does not exist
# File does not exist for patient TNBC91, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC91 as file does not exist
# File does not exist for patient TNBC92, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC92 as file does not exist
# File does not exist for patient TNBC92, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC92 as file does not exist
# File does not exist for patient TNBC92, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC92 as file does not exist
# File does not exist for patient TNBC92, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC92 as file does not exist
# File does not exist for patient TNBC92, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC92 as file does not exist
# File does not exist for patient TNBC92, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC92 as file does not exist
# File does not exist for patient TNBC92, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC92 as file does not exist
# File does not exist for patient TNBC92, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC92 as file does not exist
# File does not exist for patient TNBC92, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC92 as file does not exist
# File does not exist for patient TNBC92, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC92 as file does not exist
# File does not exist for patient TNBC92, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC92 as file does not exist
# File does not exist for patient TNBC93, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC93 as file does not exist
# File does not exist for patient TNBC93, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC93 as file does not exist
# File does not exist for patient TNBC93, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC93 as file does not exist
# File does not exist for patient TNBC93, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC93 as file does not exist
# File does not exist for patient TNBC93, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC93 as file does not exist
# File does not exist for patient TNBC93, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC93 as file does not exist
# File does not exist for patient TNBC93, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC93 as file does not exist
# File does not exist for patient TNBC93, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC93 as file does not exist
# File does not exist for patient TNBC93, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC93 as file does not exist
# File does not exist for patient TNBC93, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC93 as file does not exist
# File does not exist for patient TNBC93, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC93 as file does not exist
# File does not exist for patient TNBC94, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC94 as file does not exist
# File does not exist for patient TNBC94, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC94 as file does not exist
# File does not exist for patient TNBC94, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC94 as file does not exist
# File does not exist for patient TNBC94, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC94 as file does not exist
# File does not exist for patient TNBC94, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC94 as file does not exist
# File does not exist for patient TNBC94, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC94 as file does not exist
# File does not exist for patient TNBC94, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC94 as file does not exist
# File does not exist for patient TNBC94, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC94 as file does not exist
# File does not exist for patient TNBC94, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC94 as file does not exist
# File does not exist for patient TNBC94, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC94 as file does not exist
# File does not exist for patient TNBC94, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC94 as file does not exist
# File does not exist for patient TNBC95, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC95 as file does not exist
# File does not exist for patient TNBC95, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC95 as file does not exist
# File does not exist for patient TNBC95, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC95 as file does not exist
# File does not exist for patient TNBC95, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC95 as file does not exist
# File does not exist for patient TNBC95, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC95 as file does not exist
# File does not exist for patient TNBC95, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC95 as file does not exist
# File does not exist for patient TNBC95, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC95 as file does not exist
# File does not exist for patient TNBC95, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC95 as file does not exist
# File does not exist for patient TNBC95, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC95 as file does not exist
# File does not exist for patient TNBC95, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC95 as file does not exist
# File does not exist for patient TNBC95, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC95 as file does not exist
# File does not exist for patient TNBC96, model uni_explora_kde_4096_prototypes, type explora
# Removed patient TNBC96 as file does not exist
# File does not exist for patient TNBC96, model uni_explora_kde_16384_prototypes, type explora
# Removed patient TNBC96 as file does not exist
# File does not exist for patient TNBC96, model uni_explora_kde_65536_prototypes, type explora
# Removed patient TNBC96 as file does not exist
# File does not exist for patient TNBC96, model uni_explora_koleo_4096_prototypes, type explora
# Removed patient TNBC96 as file does not exist
# File does not exist for patient TNBC96, model uni_explora_koleo_16384_prototypes, type explora
# Removed patient TNBC96 as file does not exist
# File does not exist for patient TNBC96, model uni_explora_koleo_65536_prototypes, type explora
# Removed patient TNBC96 as file does not exist
# File does not exist for patient TNBC96, model uni_full_kde_4096_prototypes, type full
# Removed patient TNBC96 as file does not exist
# File does not exist for patient TNBC96, model uni_full_kde_16384_prototypes, type full
# Removed patient TNBC96 as file does not exist
# File does not exist for patient TNBC96, model uni_full_kde_65536_prototypes, type full
# Removed patient TNBC96 as file does not exist
# File does not exist for patient TNBC96, model uni_full_koleo_4096_prototypes, type full
# Removed patient TNBC96 as file does not exist
# File does not exist for patient TNBC96, model uni_full_koleo_16384_prototypes, type full
# Removed patient TNBC96 as file does not exist
# Removed 96 patients; remaining 0 patients.

# %%
optimal_clusters = []
df_all_summary = []
for i_p, patient in enumerate(patient_list):

    df_summary = pd.DataFrame(columns=["n_clusters", 
                                    "wasserstein_distances", 
                                    "mean_wasserstein_distance", 
                                    "std_wasserstein_distance", 
                                    "median_wasserstein_distance", 
                                    "min_wasserstein_distance", 
                                    "max_wasserstein_distance",
                                    "model_type",
                                    "params"])
    summary_list = []
    all_names = []
    wassersteins = []

    for model_type, names, benchmark_path in zip([config['retrained_model_list1_type'],
                                  config['retrained_model_list2_type']],
                                  [config['retrained_model_list1'],
                                   config['retrained_model_list2']],
                                   [config['retrained_benchmark_folder1'],
                                    config['retrained_benchmark_folder2']]):

        
        
        path_to_invasive_cancer_clustering_results = os.path.join(benchmark_path, "invasive_cancer_clustering")
        opti_clusters = pd.read_csv(os.path.join(path_to_invasive_cancer_clustering_results, "kmeans", "optimal_clusters.csv"), index_col=0)
        dfs = []
        optimal_clusters.append(opti_clusters)
        


        for name in names:

            filename = os.path.join(path_to_invasive_cancer_clustering_results, "kmeans", name, f"quantized_wasserstein_distance_molecular_raw_filtered_normalized_{name}_5_clusters_patient_{patient}.csv")

            # print(filename)
            df = pd.read_csv(filename, index_col=0)

            n_clusters = df.shape[0]
            
            # Get the lower triangular part of the matrix without the diagonal values
            lower_matrix = df.where(np.tril(np.ones(df.shape), k=-1).astype(bool))
            wasserstein_distances = lower_matrix.stack().values
            wassersteins.append(wasserstein_distances)

            if len(wasserstein_distances) == 0:
                mean_wasserstein_distance = np.nan
                std_wasserstein_distance = np.nan
                median_wasserstein_distance = np.nan
                min_wasserstein_distance = np.nan
                max_wasserstein_distance = np.nan
            else:
                mean_wasserstein_distance = np.mean(wasserstein_distances)
                std_wasserstein_distance = np.std(wasserstein_distances)
                median_wasserstein_distance = np.median(wasserstein_distances)

                min_wasserstein_distance = np.min(wasserstein_distances)
                max_wasserstein_distance = np.max(wasserstein_distances)

            if name == "uni":
                params = "base"
            else:
                params = "_".join(name.split("_")[2:])

            if name == "uni":
                params = "base"
            else:
                params = "_".join(name.split("_")[2:])

            summary_list.append({"n_clusters": n_clusters, 
                                "wasserstein_distances": wasserstein_distances, 
                                "mean_wasserstein_distance": mean_wasserstein_distance, 
                                "std_wasserstein_distance": std_wasserstein_distance, 
                                "median_wasserstein_distance": median_wasserstein_distance, 
                                "min_wasserstein_distance": min_wasserstein_distance, 
                                "max_wasserstein_distance": max_wasserstein_distance,
                                "model_type": model_type, 
                                "params": params})
            
            if name == "uni":
                name = f"uni_{model_type}"

            dfs.append(df)
            all_names.append(name)


    df_summary = pd.concat([df_summary, pd.DataFrame(summary_list)], ignore_index=True)
    df_summary.index = all_names
    df_summary['patient'] = patient
    df_all_summary.append(df_summary)




    df_sink = pd.DataFrame(wassersteins, index=all_names).T
    df_sink_melted = df_sink.melt(var_name="model", value_name="wasserstein_distance")
    df_sink_melted['model_type'] = df_sink_melted['model'].apply(lambda x: x.split("_")[1])
    df_sink_melted['param'] = df_sink_melted['model'].apply(lambda x: "_".join(x.split("_")[2:]) if len(x.split("_")) > 2 else "base")

df_spider = pd.concat(df_all_summary).reset_index().rename(columns={"index": "model"})

## Mean wasserstein distance per patient
stat = 'median'
# plt.figure(figsize=(8, 7))
# sns.barplot(df_spider, x="params", y=f"{stat}_wasserstein_distance", hue='model_type', palette={"full": "black", "explora": "lightgrey"})
# plt.xticks(rotation=90)
# sns.despine()

# plt.title(f"{stat.capitalize()} cluster quantized wasserstein distances per patient in the raw_filtered_normalized embedding \n (for models with parameters leading to the best silhouette and lower patient ARI)", weight='bold', fontsize=16)
# #plt.yscale("log")
# plt.savefig(os.path.join(config['figures_folder'], "Figure4", f"{stat}_wasserstein_distance_across_patients_in_raw_filtered_normalized_embedding.pdf"), bbox_inches='tight')

optimal_clusters = pd.concat(optimal_clusters).drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 39
#      36 filename = os.path.join(path_to_invasive_cancer_clustering_results, "kmeans", name, f"quantized_wasserstein_distance_molecular_raw_filtered_normalized_{name}_5_clusters_patient_{patient}.csv")
#      38 # print(filename)
# ---> 39 df = pd.read_csv(filename, index_col=0)
#      41 n_clusters = df.shape[0]
#      43 # Get the lower triangular part of the matrix without the diagonal values
#
# File ~/.conda/envs/digitalhisto/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.conda/envs/digitalhisto/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.conda/envs/digitalhisto/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/.conda/envs/digitalhisto/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/.conda/envs/digitalhisto/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/.conda/envs/digitalhisto/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~/.conda/envs/digitalhisto/lib/python3.10/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../results/TNBC/benchmark/uni_explora_models/invasive_cancer_clustering/kmeans/uni/quantized_wasserstein_distance_molecular_raw_filtered_normalized_uni_5_clusters_patient_TNBC1.csv'

# %%
optimal_clusters
# Out:
#                                     silhouette_score  ARI_patient  n_clusters  \
# name
# uni                                         0.423326     0.086596           5
# uni_explora_kde_16384_prototypes            0.435570     0.061118           5
# uni_explora_kde_4096_prototypes             0.437995     0.055109           4
# uni_explora_kde_65536_prototypes            0.451961     0.087589           5
# uni_explora_koleo_16384_prototypes          0.421293     0.086693           5
# uni_explora_koleo_4096_prototypes           0.433936     0.066612           5
# uni_explora_koleo_65536_prototypes          0.420049     0.075163           4
# uni_full_kde_16384_prototypes               0.490941     0.093426           9
# uni_full_kde_4096_prototypes                0.504382     0.091184           8
# uni_full_kde_65536_prototypes               0.562449     0.094217           9
# uni_full_koleo_16384_prototypes             0.544986     0.085048           8
# uni_full_koleo_4096_prototypes              0.548668     0.085252           9
# uni_full_koleo_65536_prototypes             0.544562     0.062926           5
#
#                                     euclidian_dist_to_optimal
# name
# uni                                                  0.583140
# uni_explora_kde_16384_prototypes                     0.567729
# uni_explora_kde_4096_prototypes                      0.564701
# uni_explora_kde_65536_prototypes                     0.554994
# uni_explora_koleo_16384_prototypes                   0.585165
# uni_explora_koleo_4096_prototypes                    0.569970
# uni_explora_koleo_65536_prototypes                   0.584802
# uni_full_kde_16384_prototypes                        0.517561
# uni_full_kde_4096_prototypes                         0.503936
# uni_full_kde_65536_prototypes                        0.447579
# uni_full_koleo_16384_prototypes                      0.462894
# uni_full_koleo_4096_prototypes                       0.459313
# uni_full_koleo_65536_prototypes                      0.459764

# %%
import sys
sys.path.append("../../")
from digitalhistopathology.notebooks_utils import sort_retrained_models

retrained_models = config['retrained_model_list1'] + config['retrained_model_list2']
sorted_retrained_models = sort_retrained_models(retrained_models)

print("Original order:", retrained_models)
print("Sorted order:", sorted_retrained_models)


palette = []
for model in sorted_retrained_models:
    if "explora" in model:
        palette.append("white")
    elif "full" in model:
        palette.append("black")
    else:
        palette.append("deepskyblue")
# Out:
# Original order: ['uni', 'uni_explora_kde_4096_prototypes', 'uni_explora_kde_16384_prototypes', 'uni_explora_kde_65536_prototypes', 'uni_explora_koleo_4096_prototypes', 'uni_explora_koleo_16384_prototypes', 'uni_explora_koleo_65536_prototypes', 'uni', 'uni_full_kde_4096_prototypes', 'uni_full_kde_16384_prototypes', 'uni_full_kde_65536_prototypes', 'uni_full_koleo_4096_prototypes', 'uni_full_koleo_16384_prototypes', 'uni_full_koleo_65536_prototypes']
# Sorted order: ['uni', 'uni_explora_kde_4096_prototypes', 'uni_explora_kde_16384_prototypes', 'uni_explora_kde_65536_prototypes', 'uni_full_kde_4096_prototypes', 'uni_full_kde_16384_prototypes', 'uni_full_kde_65536_prototypes', 'uni_explora_koleo_4096_prototypes', 'uni_explora_koleo_16384_prototypes', 'uni_explora_koleo_65536_prototypes', 'uni_full_koleo_4096_prototypes', 'uni_full_koleo_16384_prototypes', 'uni_full_koleo_65536_prototypes']

# %%
dfs = []
n_clusters = []
for model_type in sorted_retrained_models:
    if model_type == "uni":
        df = df_spider[df_spider['model'] == "uni_explora"]
        df['model'] = "uni"
    else:
        df = df_spider[df_spider['model'] == model_type]

    n_clusters.append(optimal_clusters.loc[model_type, 'n_clusters'])
    dfs.append(df)
df = pd.concat(dfs, ignore_index=True)

plt.figure(figsize=(15, 4))
sns.barplot(data=df, x='model', y="median_wasserstein_distance", 
palette=palette, 
# palette=["deepskyblue", "white", "white", "white","black", 
#           "black", "black", "white", "white", "white", 
#         "black", "black", "black", ],
                     linewidth=2,
            edgecolor="black", capsize=0.2
)
plt.xticks(rotation=90)
plt.ylabel("wasserstein distance")
plt.xlabel("Model")
plt.title(f"{stat.capitalize()} cluster quantized wasserstein distances per patient in the raw filtered embedding \n (for models with parameters leading to the best silhouette and lower patient ARI)", weight='bold', fontsize=16)
sns.despine()

for i, n in enumerate(n_clusters):
    # plt.text(x=i, y=13000, s=f"n={n}", ha='center', va='bottom', weight='bold')
    plt.text(x=i, y=2000, s=f"n=5", ha='center', va='bottom', weight='bold')




plt.savefig(os.path.join(config['figures_folder'], "Figure4", f"quantized_wasserstein_between_image_clusters_in_raw filtered_embedding_per_patient.pdf"), bbox_inches='tight')

# %%
optimal_clusters = []
df_all_summary = []


for i_p, patient in enumerate(patient_list):

    df_summary = pd.DataFrame(columns=["n_clusters", 
                                    "wasserstein_distances", 
                                    "mean_wasserstein_distance", 
                                    "std_wasserstein_distance", 
                                    "median_wasserstein_distance", 
                                    "min_wasserstein_distance", 
                                    "max_wasserstein_distance",
                                    "model_type",
                                    "params"])
    summary_list = []
    all_names = []
    wassersteins = []


    for model_type, names, benchmark_path in zip([config['retrained_model_list1_type'],
                                  config['retrained_model_list2_type']],
                                  [config['retrained_model_list1'],
                                   config['retrained_model_list2']],
                                   [config['retrained_benchmark_folder1'],
                                    config['retrained_benchmark_folder2']]):

        
        
        path_to_invasive_cancer_clustering_results = os.path.join(benchmark_path, "invasive_cancer_clustering")
        opti_clusters = pd.read_csv(os.path.join(path_to_invasive_cancer_clustering_results, "kmeans", "optimal_clusters.csv"), index_col=0)
        dfs = []
        optimal_clusters.append(opti_clusters)
        
        


        for name in names:

            # print(f"model_type: {name}, optimal clusters: {opti_clusters.loc[name, 'n_clusters']}")

            
        # print(os.path.join(path_to_invasive_cancer_clustering_results, "kmeans", name, f"quantized_wasserstein_distance_molecular_combat_corrected_{name}_{opti_clusters.loc[name, 'n_clusters']}_clusters_patient_{patient}.csv"))
            # filename = os.path.join(path_to_invasive_cancer_clustering_results, "kmeans", name, f"quantized_wasserstein_distance_molecular_combat_corrected_{name}_{opti_clusters.loc[name, 'n_clusters']}_clusters_patient_{patient}.csv")
            filename = os.path.join(path_to_invasive_cancer_clustering_results, "kmeans", name, f"quantized_wasserstein_distance_molecular_combat_corrected_{name}_5_clusters_patient_{patient}.csv")

            # print(filename)
            df = pd.read_csv(filename, index_col=0)

            n_clusters = df.shape[0]
            
            # Get the lower triangular part of the matrix without the diagonal values
            lower_matrix = df.where(np.tril(np.ones(df.shape), k=-1).astype(bool))
            wasserstein_distances = lower_matrix.stack().values
            wassersteins.append(wasserstein_distances)

            if len(wasserstein_distances) == 0:
                mean_wasserstein_distance = np.nan
                std_wasserstein_distance = np.nan
                median_wasserstein_distance = np.nan
                min_wasserstein_distance = np.nan
                max_wasserstein_distance = np.nan
            else:
                mean_wasserstein_distance = np.mean(wasserstein_distances)
                std_wasserstein_distance = np.std(wasserstein_distances)
                median_wasserstein_distance = np.median(wasserstein_distances)

                min_wasserstein_distance = np.min(wasserstein_distances)
                max_wasserstein_distance = np.max(wasserstein_distances)

            if name == "uni":
                params = "base"
            else:
                params = "_".join(name.split("_")[2:])

            summary_list.append({"n_clusters": n_clusters, 
                                "wasserstein_distances": wasserstein_distances, 
                                "mean_wasserstein_distance": mean_wasserstein_distance, 
                                "std_wasserstein_distance": std_wasserstein_distance, 
                                "median_wasserstein_distance": median_wasserstein_distance, 
                                "min_wasserstein_distance": min_wasserstein_distance, 
                                "max_wasserstein_distance": max_wasserstein_distance,
                                "model_type": model_type, 
                                "params": params})
            
            if name == "uni":
                name = f"uni_{model_type}"

            dfs.append(df)
            all_names.append(name)


    df_summary = pd.concat([df_summary, pd.DataFrame(summary_list)], ignore_index=True)
    df_summary.index = all_names
    df_summary['patient'] = patient
    df_all_summary.append(df_summary)




    df_sink = pd.DataFrame(wassersteins, index=all_names).T
    df_sink_melted = df_sink.melt(var_name="model", value_name="wasserstein_distance")
    df_sink_melted['model_type'] = df_sink_melted['model'].apply(lambda x: x.split("_")[1])
    df_sink_melted['param'] = df_sink_melted['model'].apply(lambda x: "_".join(x.split("_")[2:]) if len(x.split("_")) > 2 else "base")


df_spider = pd.concat(df_all_summary).reset_index().rename(columns={"index": "model"})

## Mean wasserstein distance per patient
# stat = 'median'
# plt.figure(figsize=(8, 7))
# sns.barplot(df_spider, x="params", y=f"{stat}_wasserstein_distance", hue='model_type', palette={"full": "black", "explora": "lightgrey"})
# plt.xticks(rotation=90)
# sns.despine()

# plt.title(f"{stat.capitalize()} cluster quantized wasserstein distances per patient in the combat_corrected embedding \n (for models with parameters leading to the best silhouette and lower patient ARI)", weight='bold', fontsize=16)
# #plt.yscale("log")
# plt.savefig(os.path.join(config['figures_folder'], "Figure4", f"{stat}_wasserstein_distance_across_patients_in_combat_corrected_embedding.pdf"), bbox_inches='tight')

optimal_clusters = pd.concat(optimal_clusters).drop_duplicates()

stat = 'median'

# %%
dfs = []
n_clusters = []
for model_type in sorted_retrained_models:
    if model_type == "uni":
        df = df_spider[df_spider['model'] == "uni_explora"]
        df['model'] = "uni"
    else:
        df = df_spider[df_spider['model'] == model_type]

    n_clusters.append(optimal_clusters.loc[model_type, 'n_clusters'])
    dfs.append(df)
df = pd.concat(dfs, ignore_index=True)

plt.figure(figsize=(15, 4))
sns.barplot(data=df, x='model', y="median_wasserstein_distance", 
palette=palette, 
                     linewidth=2,
            edgecolor="black", capsize=0.2
)
plt.xticks(rotation=90)
plt.ylabel("wasserstein distance")
plt.xlabel("Model")
plt.title(f"{stat.capitalize()} cluster quantized wasserstein distances per patient in the combat_corrected embedding \n (for models with parameters leading to the best silhouette and lower patient ARI)", weight='bold', fontsize=16)
sns.despine()

for i, n in enumerate(n_clusters):
    # plt.text(x=i, y=12000, s=f"n={n}", ha='center', va='bottom', weight='bold')
    plt.text(x=i, y=14000, s=f"n=5", ha='center', va='bottom', weight='bold')



plt.savefig(os.path.join(config['figures_folder'], "Figure4", f"quantized_wasserstein_between_image_clusters_in_combat_corrected_embedding_per_patient.pdf"), bbox_inches='tight')

# %%
df_summary = pd.DataFrame(columns=["n_clusters", 
                                   "wasserstein_distances", 
                                   "mean_wasserstein_distance", 
                                   "std_wasserstein_distance", 
                                   "median_wasserstein_distance", 
                                   "min_wasserstein_distance", 
                                   "max_wasserstein_distance",
                                   "model_type",
                                   "params"])
summary_list = []
all_names = []
wassersteins = []
optimal_clusters = pd.DataFrame()
for model_type, names, path in zip([config['retrained_model_list1_type'],
                             config['retrained_model_list2_type']],
                             [config['retrained_model_list1'],
                              config['retrained_model_list2']],
                              [config['retrained_benchmark_folder1'],
                               config['retrained_benchmark_folder2']]):
    
    path_to_invasive_cancer_clustering_results = os.path.join(path, "invasive_cancer_clustering", config['invasive_cancer_clustering_algo'])
    opti_clusters = pd.read_csv(os.path.join(path_to_invasive_cancer_clustering_results, "optimal_clusters.csv"), index_col=0)
    dfs = []

    
    


    for name in names:
        # print(os.path.join(path_to_invasive_cancer_clustering_results, name, f"quantized_wasserstein_distance_{name}_{opti_clusters.loc[name, 'n_clusters']}_clusters.csv"))
        filename = os.path.join(path_to_invasive_cancer_clustering_results, name, f"quantized_wasserstein_distance_{name}_molecular_combat_corrected_5_clusters.csv")
        df = pd.read_csv(filename, index_col=0)

        n = opti_clusters.loc[name, 'n_clusters']
        optimal_clusters.loc[name, 'n_clusters'] = n

        n_clusters = df.shape[0]      
        # Get the lower triangular part of the matrix without the diagonal values
        lower_matrix = df.where(np.tril(np.ones(df.shape), k=-1).astype(bool))
        wasserstein_distances = lower_matrix.stack().values
        wassersteins.append(wasserstein_distances)


        mean_wasserstein_distance = np.mean(wasserstein_distances)
        std_wasserstein_distance = np.std(wasserstein_distances)
        median_wasserstein_distance = np.median(wasserstein_distances)

        min_wasserstein_distance = np.min(wasserstein_distances)
        max_wasserstein_distance = np.max(wasserstein_distances)

        if name == "uni":
            params = "base"
        else:
            params = "_".join(name.split("_")[2:])

        summary_list.append({"n_clusters": n_clusters, 
                            "wasserstein_distances": wasserstein_distances, 
                            "mean_wasserstein_distance": mean_wasserstein_distance, 
                            "std_wasserstein_distance": std_wasserstein_distance, 
                            "median_wasserstein_distance": median_wasserstein_distance, 
                            "min_wasserstein_distance": min_wasserstein_distance, 
                            "max_wasserstein_distance": max_wasserstein_distance,
                            "model_type": model_type, 
                            "params": params})
        
        if name == "uni":
            name = f"uni_{model_type}"

        dfs.append(df)
        all_names.append(name)

df_summary = pd.concat([df_summary, pd.DataFrame(summary_list)], ignore_index=True)
df_summary.index = all_names




df_sink = pd.DataFrame(wassersteins, index=all_names).T
df_sink_melted = df_sink.melt(var_name="model", value_name="wasserstein_distance")
df_sink_melted['model_type'] = df_sink_melted['model'].apply(lambda x: x.split("_")[1])
df_sink_melted['param'] = df_sink_melted['model'].apply(lambda x: "_".join(x.split("_")[2:]) if len(x.split("_")) > 2 else "base")

# %%
dfs = []
n_clusters = []

import sys
sys.path.append("../../")
from digitalhistopathology.notebooks_utils import sort_retrained_models

sorted_models = sort_retrained_models(config['retrained_model_list1'] + config['retrained_model_list2'])
for model_type in sorted_models:
    if model_type == "uni":
        df = df_sink_melted[df_sink_melted['model'] == "uni_explora"]
        df['model'] = "uni"
        n_clusters.append(df_summary.loc['uni_explora', 'n_clusters'])
    else:
        df = df_sink_melted[df_sink_melted['model'] == model_type]
        n_clusters.append(df_summary.loc[model_type, 'n_clusters'])
    dfs.append(df)
df = pd.concat(dfs, ignore_index=True)


palette = []
for model in sorted_models:
    if "explora" in model:
        palette.append("white")
    elif "full" in model:
        palette.append("black")
    else:
        palette.append("deepskyblue")

plt.figure(figsize=(15, 4))
sns.barplot(data=df, x='model', 
            y="wasserstein_distance", 
            palette=palette, 
            linewidth=2,
            edgecolor="black",
            capsize=0.2,
)
plt.xticks(rotation=90)
plt.ylabel("wasserstein distance")
plt.xlabel("Model")
plt.title(f"Quantized wasserstein distances in the combat corrected molecular embedding\n for models with parameters leading to the best silhouette and lower patient ARI", weight="bold", fontsize=14)
sns.despine()

for i, n in enumerate(n_clusters):
    plt.text(x=i, y=15500, s=f"n=5", ha='center', va='bottom', weight='bold')

plt.savefig(os.path.join(config['figures_folder'], "Figure4/invasive_cancer_clustering_quantized_wasserstein_distances_molecular_combat_corrected_embedding_for_clusters_defined_with_best_silhouette_and_lower_ARI_patient.pdf"), bbox_inches="tight")
