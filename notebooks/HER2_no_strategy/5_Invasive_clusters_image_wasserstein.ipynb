# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
import os
import json
import matplotlib
matplotlib.rcParams["pdf.fonttype"] = 42
matplotlib.rcParams["ps.fonttype"] = 42

import warnings
warnings.filterwarnings("ignore")

import glob



import json

# %%
with open("../../config/config_notebooks_HER2.json", "r") as config_file:
    config = json.load(config_file)

# %%
df_summary = pd.DataFrame(columns=["n_clusters", 
                                   "wasserstein_distances", 
                                   "mean_wasserstein_distance", 
                                   "std_wasserstein_distance", 
                                   "median_wasserstein_distance", 
                                   "min_wasserstein_distance", 
                                   "max_wasserstein_distance",
                                   "model_type",
                                   "params"])
summary_list = []
all_names = []
wassersteins = []
optimal_clusters = pd.DataFrame()
for model_type, names, path in zip([config['retrained_model_list1_type'],
                             config['retrained_model_list2_type']],
                             [config['retrained_model_list1'],
                              config['retrained_model_list2']],
                              [config['retrained_benchmark_folder1'],
                               config['retrained_benchmark_folder2']]):
    
    path_to_invasive_cancer_clustering_results = os.path.join(path, "invasive_cancer_clustering_strategy_silhouette_and_batch_effect", config['invasive_cancer_clustering_algo'])
    opti_clusters = pd.read_csv(os.path.join(path_to_invasive_cancer_clustering_results, "opti_clusters.csv"), index_col=0)
    print(opti_clusters)
    dfs = []

    
    


    for name in names:
        print(os.path.join(path_to_invasive_cancer_clustering_results, name, f"quantized_wasserstein_distance_{name}_{opti_clusters.loc[name, 'n_clusters']}_clusters.csv"))
        filename = os.path.join(path_to_invasive_cancer_clustering_results, name, f"quantized_wasserstein_distance_{name}_{opti_clusters.loc[name, 'n_clusters']}_clusters.csv")
        df = pd.read_csv(filename, index_col=0)

        n = opti_clusters.loc[name, 'n_clusters']
        optimal_clusters.loc[name, 'n_clusters'] = n

        n_clusters = df.shape[0]      
        # Get the lower triangular part of the matrix without the diagonal values
        lower_matrix = df.where(np.tril(np.ones(df.shape), k=-1).astype(bool))
        wasserstein_distances = lower_matrix.stack().values
        wassersteins.append(wasserstein_distances)


        mean_wasserstein_distance = np.mean(wasserstein_distances)
        std_wasserstein_distance = np.std(wasserstein_distances)
        median_wasserstein_distance = np.median(wasserstein_distances)

        min_wasserstein_distance = np.min(wasserstein_distances)
        max_wasserstein_distance = np.max(wasserstein_distances)

        if name == "uni":
            params = "base"
        else:
            params = "_".join(name.split("_")[2:])

        summary_list.append({"n_clusters": n_clusters, 
                            "wasserstein_distances": wasserstein_distances, 
                            "mean_wasserstein_distance": mean_wasserstein_distance, 
                            "std_wasserstein_distance": std_wasserstein_distance, 
                            "median_wasserstein_distance": median_wasserstein_distance, 
                            "min_wasserstein_distance": min_wasserstein_distance, 
                            "max_wasserstein_distance": max_wasserstein_distance,
                            "model_type": model_type, 
                            "params": params})
        
        if name == "uni":
            name = f"uni_{model_type}"

        dfs.append(df)
        all_names.append(name)

df_summary = pd.concat([df_summary, pd.DataFrame(summary_list)], ignore_index=True)
df_summary.index = all_names




df_sink = pd.DataFrame(wassersteins, index=all_names).T
df_sink_melted = df_sink.melt(var_name="model", value_name="wasserstein_distance")
df_sink_melted['model_type'] = df_sink_melted['model'].apply(lambda x: x.split("_")[1])
df_sink_melted['param'] = df_sink_melted['model'].apply(lambda x: "_".join(x.split("_")[2:]) if len(x.split("_")) > 2 else "base")

plt.figure(figsize=(10, 5))
sns.barplot(data=df_sink_melted, x="param", y="wasserstein_distance", hue="model_type", palette={"full": "black", "explora": "lightgrey"})
plt.xticks(rotation=90)
plt.ylabel("wasserstein distance")
plt.xlabel("Model")
plt.title(f"Quantized wasserstein distances in the image embedding\n for models with parameters leading to the best silhouette and lower patient ARI", weight="bold", fontsize=14)


for i, model_type in enumerate(df_summary['model_type'].unique()):
    for j in range(len(df_summary[df_summary['model_type'] == model_type])):
        distances = df_summary[df_summary['model_type'] == model_type]["mean_wasserstein_distance"].values
        deviations = df_summary[df_summary['model_type'] == model_type]["std_wasserstein_distance"].values
        nb_clusters = df_summary[df_summary['model_type'] == model_type]["n_clusters"].values
        if i == 0:
            plt.text(j - 0.2, distances[j]+120, f"n={nb_clusters[j]}", ha='center', va='bottom', weight='bold')
        else:
            plt.text(j + 0.2, distances[j]+120, f"n={nb_clusters[j]}", ha='center', va='bottom', weight='bold')

sns.despine()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.savefig(os.path.join(config['figures_folder'], "Figure4/invasive_cancer_clustering_quantized_wasserstein_distances_image_embedding_for_clusters_defined_with_best_silhouette_and_lower_ARI_patient.pdf"), bbox_inches="tight")
#plt.tight_layout()
# Out:
#                                     n_neighbors  data  \
# name
# uni                                         400  umap
# uni_explora_kde_16384_prototypes            350  umap
# uni_explora_kde_4096_prototypes             400  umap
# uni_explora_kde_65536_prototypes            350  umap
# uni_explora_koleo_16384_prototypes          200  umap
# uni_explora_koleo_4096_prototypes           300  umap
# uni_explora_koleo_65536_prototypes          300  umap
#
#                                                                                labels  \
# name
# uni                                 [4, 0, 4, 0, 4, 0, 3, 5, 0, 2, 0, 5, 5, 2, 4, ...
# uni_explora_kde_16384_prototypes    [8, 0, 8, 8, 8, 8, 8, 6, 0, 8, 8, 0, 0, 8, 8, ...
# uni_explora_kde_4096_prototypes     [8, 2, 2, 2, 2, 2, 8, 8, 8, 2, 8, 8, 8, 7, 2, ...
# uni_explora_kde_65536_prototypes    [0, 2, 0, 4, 0, 4, 4, 4, 2, 2, 2, 4, 0, 0, 2, ...
# uni_explora_koleo_16384_prototypes  [2, 2, 2, 2, 2, 2, 2, 2, 0, 0, 2, 2, 0, 2, 2, ...
# uni_explora_koleo_4096_prototypes   [3, 3, 8, 3, 7, 8, 8, 6, 3, 3, 8, 3, 3, 7, 8, ...
# uni_explora_koleo_65536_prototypes  [8, 8, 1, 8, 1, 1, 8, 8, 8, 8, 1, 8, 8, 8, 1, ...
#
#                                     cluster_number  silhouette_score  \
# name
# uni                                              7          0.398679
# uni_explora_kde_16384_prototypes                 9          0.456748
# uni_explora_kde_4096_prototypes                  9          0.462028
# uni_explora_kde_65536_prototypes                 9          0.471493
# uni_explora_koleo_16384_prototypes               6          0.449178
# uni_explora_koleo_4096_prototypes                9          0.445381
# uni_explora_koleo_65536_prototypes               9          0.474809
#
#                                          inertia  davies_bouldin_score  \
# name
# uni                                 47139.692504              0.797120
# uni_explora_kde_16384_prototypes    34833.966080              0.785938
# uni_explora_kde_4096_prototypes     34567.659307              0.725125
# uni_explora_kde_65536_prototypes    35983.899232              0.727600
# uni_explora_koleo_16384_prototypes  54468.383743              0.759846
# uni_explora_koleo_4096_prototypes   33837.726362              0.714093
# uni_explora_koleo_65536_prototypes  28133.238712              0.684829
#
#                                     calinski_harabasz_score  ARI_patient  \
# name
# uni                                            72041.846146     0.266123
# uni_explora_kde_16384_prototypes              139341.278604     0.408463
# uni_explora_kde_4096_prototypes               129614.539538     0.432428
# uni_explora_kde_65536_prototypes              133092.377230     0.330043
# uni_explora_koleo_16384_prototypes             90633.783773     0.399611
# uni_explora_koleo_4096_prototypes              90076.592888     0.373236
# uni_explora_koleo_65536_prototypes            100472.382811     0.420406
#
#                                     n_clusters  min_dist  \
# name
# uni                                          7  0.100000
# uni_explora_kde_16384_prototypes             9  0.000999
# uni_explora_kde_4096_prototypes              9  0.001000
# uni_explora_kde_65536_prototypes             9  0.001000
# uni_explora_koleo_16384_prototypes           6  0.001000
# uni_explora_koleo_4096_prototypes            9  0.001000
# uni_explora_koleo_65536_prototypes           9  0.001000
#
#                                     euclidian_dist_to_optimal  \
# name
# uni                                                  0.657577
# uni_explora_kde_16384_prototypes                     0.679680
# uni_explora_kde_4096_prototypes                      0.690223
# uni_explora_kde_65536_prototypes                     0.623096
# uni_explora_koleo_16384_prototypes                   0.680510
# uni_explora_koleo_4096_prototypes                    0.668511
# uni_explora_koleo_65536_prototypes                   0.672731
#
#                                     batch_effect_mitigation
# name
# uni                                                0.733877
# uni_explora_kde_16384_prototypes                   0.591537
# uni_explora_kde_4096_prototypes                    0.567572
# uni_explora_kde_65536_prototypes                   0.669957
# uni_explora_koleo_16384_prototypes                 0.600389
# uni_explora_koleo_4096_prototypes                  0.626764
# uni_explora_koleo_65536_prototypes                 0.579594
# ../../results/HER2/benchmark/uni_explora_models/invasive_cancer_clustering_strategy_silhouette_and_batch_effect/kmeans/uni/quantized_wasserstein_distance_uni_7_clusters.csv
# ../../results/HER2/benchmark/uni_explora_models/invasive_cancer_clustering_strategy_silhouette_and_batch_effect/kmeans/uni_explora_kde_4096_prototypes/quantized_wasserstein_distance_uni_explora_kde_4096_prototypes_9_clusters.csv
# ../../results/HER2/benchmark/uni_explora_models/invasive_cancer_clustering_strategy_silhouette_and_batch_effect/kmeans/uni_explora_kde_16384_prototypes/quantized_wasserstein_distance_uni_explora_kde_16384_prototypes_9_clusters.csv
# ../../results/HER2/benchmark/uni_explora_models/invasive_cancer_clustering_strategy_silhouette_and_batch_effect/kmeans/uni_explora_kde_65536_prototypes/quantized_wasserstein_distance_uni_explora_kde_65536_prototypes_9_clusters.csv
# ../../results/HER2/benchmark/uni_explora_models/invasive_cancer_clustering_strategy_silhouette_and_batch_effect/kmeans/uni_explora_koleo_4096_prototypes/quantized_wasserstein_distance_uni_explora_koleo_4096_prototypes_9_clusters.csv
# ../../results/HER2/benchmark/uni_explora_models/invasive_cancer_clustering_strategy_silhouette_and_batch_effect/kmeans/uni_explora_koleo_16384_prototypes/quantized_wasserstein_distance_uni_explora_koleo_16384_prototypes_6_clusters.csv
# ../../results/HER2/benchmark/uni_explora_models/invasive_cancer_clustering_strategy_silhouette_and_batch_effect/kmeans/uni_explora_koleo_65536_prototypes/quantized_wasserstein_distance_uni_explora_koleo_65536_prototypes_9_clusters.csv
#                                  n_neighbors  data  \
# name
# uni                                      400  umap
# uni_full_kde_16384_prototypes            100  umap
# uni_full_kde_4096_prototypes             400  umap
# uni_full_kde_65536_prototypes            350  umap
# uni_full_koleo_16384_prototypes          150  umap
# uni_full_koleo_4096_prototypes           200  umap
# uni_full_koleo_65536_prototypes          400  umap
#
#                                                                             labels  \
# name
# uni                              [4, 0, 4, 0, 4, 0, 3, 5, 0, 2, 0, 5, 5, 2, 4, ...
# uni_full_kde_16384_prototypes    [4, 4, 4, 4, 4, 4, 0, 2, 2, 0, 0, 4, 4, 4, 4, ...
# uni_full_kde_4096_prototypes     [8, 4, 8, 8, 1, 6, 6, 1, 8, 1, 1, 1, 8, 8, 1, ...
# uni_full_kde_65536_prototypes    [0, 0, 0, 0, 0, 2, 2, 0, 2, 0, 2, 2, 0, 0, 0, ...
# uni_full_koleo_16384_prototypes  [0, 0, 0, 0, 0, 2, 0, 0, 2, 0, 0, 2, 0, 0, 0, ...
# uni_full_koleo_4096_prototypes   [4, 3, 4, 1, 1, 1, 3, 4, 3, 4, 4, 4, 1, 1, 4, ...
# uni_full_koleo_65536_prototypes  [0, 0, 0, 0, 0, 0, 2, 0, 0, 0, 0, 0, 0, 2, 0, ...
#
#                                  cluster_number  silhouette_score  \
# name
# uni                                           7          0.398679
# uni_full_kde_16384_prototypes                 8          0.513531
# uni_full_kde_4096_prototypes                  9          0.475296
# uni_full_kde_65536_prototypes                 6          0.513426
# uni_full_koleo_16384_prototypes               4          0.559090
# uni_full_koleo_4096_prototypes                9          0.435185
# uni_full_koleo_65536_prototypes               5          0.532718
#
#                                        inertia  davies_bouldin_score  \
# name
# uni                               47139.692504              0.797120
# uni_full_kde_16384_prototypes     63069.704122              0.711599
# uni_full_kde_4096_prototypes      47024.517775              0.714727
# uni_full_kde_65536_prototypes     84306.241493              0.646030
# uni_full_koleo_16384_prototypes  114972.744694              0.593294
# uni_full_koleo_4096_prototypes    42939.764158              0.740895
# uni_full_koleo_65536_prototypes   60993.524517              0.650870
#
#                                  calinski_harabasz_score  ARI_patient  \
# name
# uni                                         72041.846146     0.266123
# uni_full_kde_16384_prototypes              131486.028857     0.260720
# uni_full_kde_4096_prototypes               111871.085309     0.229554
# uni_full_kde_65536_prototypes              411754.635307     0.228752
# uni_full_koleo_16384_prototypes            101472.902104     0.221157
# uni_full_koleo_4096_prototypes              83362.807264     0.235848
# uni_full_koleo_65536_prototypes            112701.273469     0.283769
#
#                                  n_clusters  min_dist  \
# name
# uni                                       7     0.100
# uni_full_kde_16384_prototypes             8     0.001
# uni_full_kde_4096_prototypes              9     0.001
# uni_full_kde_65536_prototypes             6     0.001
# uni_full_koleo_16384_prototypes           4     0.001
# uni_full_koleo_4096_prototypes            9     0.001
# uni_full_koleo_65536_prototypes           5     0.001
#
#                                  euclidian_dist_to_optimal  \
# name
# uni                                               0.657577
# uni_full_kde_16384_prototypes                     0.551930
# uni_full_kde_4096_prototypes                      0.572721
# uni_full_kde_65536_prototypes                     0.537663
# uni_full_koleo_16384_prototypes                   0.493267
# uni_full_koleo_4096_prototypes                    0.612078
# uni_full_koleo_65536_prototypes                   0.546697
#
#                                  batch_effect_mitigation
# name
# uni                                             0.733877
# uni_full_kde_16384_prototypes                   0.739280
# uni_full_kde_4096_prototypes                    0.770446
# uni_full_kde_65536_prototypes                   0.771248
# uni_full_koleo_16384_prototypes                 0.778843
# uni_full_koleo_4096_prototypes                  0.764152
# uni_full_koleo_65536_prototypes                 0.716231
# ../../results/HER2/benchmark/uni_full_models/invasive_cancer_clustering_strategy_silhouette_and_batch_effect/kmeans/uni/quantized_wasserstein_distance_uni_7_clusters.csv
# ../../results/HER2/benchmark/uni_full_models/invasive_cancer_clustering_strategy_silhouette_and_batch_effect/kmeans/uni_full_kde_4096_prototypes/quantized_wasserstein_distance_uni_full_kde_4096_prototypes_9_clusters.csv
# ../../results/HER2/benchmark/uni_full_models/invasive_cancer_clustering_strategy_silhouette_and_batch_effect/kmeans/uni_full_kde_16384_prototypes/quantized_wasserstein_distance_uni_full_kde_16384_prototypes_8_clusters.csv
# ../../results/HER2/benchmark/uni_full_models/invasive_cancer_clustering_strategy_silhouette_and_batch_effect/kmeans/uni_full_kde_65536_prototypes/quantized_wasserstein_distance_uni_full_kde_65536_prototypes_6_clusters.csv
# ../../results/HER2/benchmark/uni_full_models/invasive_cancer_clustering_strategy_silhouette_and_batch_effect/kmeans/uni_full_koleo_4096_prototypes/quantized_wasserstein_distance_uni_full_koleo_4096_prototypes_9_clusters.csv
# ../../results/HER2/benchmark/uni_full_models/invasive_cancer_clustering_strategy_silhouette_and_batch_effect/kmeans/uni_full_koleo_16384_prototypes/quantized_wasserstein_distance_uni_full_koleo_16384_prototypes_4_clusters.csv
# ../../results/HER2/benchmark/uni_full_models/invasive_cancer_clustering_strategy_silhouette_and_batch_effect/kmeans/uni_full_koleo_65536_prototypes/quantized_wasserstein_distance_uni_full_koleo_65536_prototypes_5_clusters.csv

# %%
dfs = []
n_clusters = []

for model_type in ["uni",
              "uni_explora_kde_4096_prototypes",
              "uni_explora_kde_16384_prototypes",
                "uni_explora_kde_65536_prototypes",
                "uni_full_kde_4096_prototypes",
                "uni_full_kde_16384_prototypes",
                "uni_full_kde_65536_prototypes",
                "uni_explora_koleo_4096_prototypes",
                "uni_explora_koleo_16384_prototypes",
                "uni_explora_koleo_65536_prototypes",
                "uni_full_koleo_4096_prototypes",
                "uni_full_koleo_16384_prototypes",
                "uni_full_koleo_65536_prototypes"]:
    if model_type == "uni":
        df = df_sink_melted[df_sink_melted['model'] == "uni_explora"]
        df['model'] = "uni"
        n_clusters.append(df_summary.loc['uni_explora', 'n_clusters'])
    else:
        df = df_sink_melted[df_sink_melted['model'] == model_type]
        n_clusters.append(df_summary.loc[model_type, 'n_clusters'])
    dfs.append(df)
df = pd.concat(dfs, ignore_index=True)

plt.figure(figsize=(15, 4))
sns.barplot(data=df, x='model', y="wasserstein_distance", 
# palette=["deepskyblue", "white", "white", "white", "white", "white", "black", 
#          "black", "black","black", "black", "white", "white", "white", 
#          "white", "white", "black", "black", "black", "black","black", ], 
palette=["deepskyblue", "white", "white", "white", "black", 
         "black", "black", "white", "white", "white", 
         "black", "black", "black"], 
                     linewidth=2,
            edgecolor="black",
            capsize=0.2,
)
plt.xticks(rotation=90)
plt.ylabel("wasserstein distance")
plt.xlabel("Model")
plt.title(f"Quantized wasserstein distances in the image embedding\n for models with parameters leading to the best silhouette and lower patient ARI", weight="bold", fontsize=14)
sns.despine()

for i, n in enumerate(n_clusters):
    plt.text(x=i, y=1790, s=f"n={n}", ha='center', va='bottom', weight='bold')

plt.savefig(os.path.join(config['figures_folder'], "Figure4/invasive_cancer_clustering_quantized_wasserstein_distances_image_embedding_for_clusters_defined_with_best_silhouette_and_lower_ARI_patient.pdf"), bbox_inches="tight")
